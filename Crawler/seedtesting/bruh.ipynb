# %%
import pandas as pd

# %%
def proper_crawl_test(crawl_session):
    # print reports of iterations, iterations match up with indexing of pages, proper amount of pages are indexed
    print(f"Testing crawl session: {crawl_session}")

    report = pd.DataFrame({
        "Metric": ["Total Duration", "Average URL crawl duration", "Depth Crawled", "URLS stored"],
        "Value": ["N/A", "N/A", "N/A", "N/A"]
    })

    print(report)

# %%
def seed_testing(file):
    # set up 15 different seeds for testing

    seeds = []
    for i in range(1, 6):
        load_data = pd.read_csv(f'test{i}.csv')
        seeds.append(load_data)

    # parse urls into seed tester, iterates for every seed.txt

    # parse in the three txt files from testing
    for i in range(len(seeds)):
        print(f"Iteration: {i} with seed {seeds[i]}")
        proper_crawl_test(seeds[i])
